# %% [markdown]
# <a href="https://colab.research.google.com/github/huliyao1115/Hello-world/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def lennard_jones_potential (r, epsilon,sigma):
  "calculate the Lennard-Jones potential between two particles."
  Parameters:
  -r(float): distance between the two particles.
  epsilon (float): depth of the potential well.
  sigma(float): finite distance at which the inter-particle potential is zero.
  Returns:
  V (float):lennard-jones potential.
  V = 4*epsilon*((sigma/r)**12-(sigma/r)**6)
  return V
# Out:
#   File "<ipython-input-2-a2f7c7879211>", line 3
#     Parameters:
#                ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import matplotlib.pyplot as plt

# Boltzmann's constant, J/K
kB = 1.381e-23


# The Lennard-Jones parameters:
A =1.024e-23        # J.nm^6
B =1.582e-26        # J.nm^12

# Adjust the units of A and B - they have more manageable values in K·nm^6 and K·nm^12

result_a = A/kB
result_b = B/kB


# Interatomic distance, in nm

r= np. linspace(start=0.2,stop=4,num=400)

# Interatomic potential
U = (result_b/r**12-result_a/r**6)

# Interatomic Force
F = (12*result_b/r**13)-6*result_a/r**7



line1 = plt.plot(r,U,lw=2,color='blue',label="LJ Potential")
plt.xlim(0.2,2)
plt.ylim(-130,50)
plt.axhline(y=0, color='black')
plt.xlabel("Distance(r)")
plt.ylabel("U(r)(K))")
plt.axvline(x=3, color='orange', linestyle='--')


plt.twinx( )
line2= plt.plot(r,F,ls=':',lw=2,color='red')
plt.xlim(0.2,2)
plt.ylim(-900,200)
plt.ylabel("Force")
plt.title("Interatomic Potential VS Interatomic Force")

# jump through some hoops to get the both line's labels in the same legend:
handles = [line1, line2]
lines = line1 + line2
labels= [ ]
for line in lines:
  labels.append (line.get_label())

plt.legend ()
plt.show
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <function matplotlib.pyplot.show(close=None, block=None)>
