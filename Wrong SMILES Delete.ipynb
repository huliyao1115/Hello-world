# %% [markdown]
# <a href="https://colab.research.google.com/github/huliyao1115/Hello-world/blob/main/Wrong%20SMILES%20Delete.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('Wrong_SMILES_Delete.csv')
print(df)
# Out:
#      Surface_Area  Pore_Volume  Pressure  Temperature METAL  \
# 0          1270.0         0.71      0.15          298    Cu
# 1          1270.0         0.71      1.00          298    Cu
# 2          1270.0         0.71      1.00          313    Cu
# 3          2833.0         1.04     35.00          298    Zn
# 4          1568.0         1.07     35.00          298    Zn
# ..            ...          ...       ...          ...   ...
# 162         147.0         0.10      1.00          298    Cu
# 163        2850.0         1.00      1.00          273    Cu
# 164        2850.0         1.00      0.15          273    Cu
# 165         704.0         0.28      1.00          298    Zn
# 166         704.0         0.28      0.15          298    Zn
#
#                                 SMILE_Organic_linker_1  Atomic_Number  \
# 0                    OC(=O)C1=CC(=CC(=C1)C(O)=O)C(O)=O             29
# 1                    OC(=O)C1=CC(=CC(=C1)C(O)=O)C(O)=O             29
# ...

# %%
# Drop all the orbital columns
df.drop(['1s', '2s', '2p', '3s', '3p', '3d', '4s', '4p', '4d', '4f', '5s', '5p'],axis=1,inplace=True)

# %%
df
# Out:
#      Surface_Area  Pore_Volume  Pressure  Temperature METAL  \
# 0          1270.0         0.71      0.15          298    Cu
# 1          1270.0         0.71      1.00          298    Cu
# 2          1270.0         0.71      1.00          313    Cu
# 3          2833.0         1.04     35.00          298    Zn
# 4          1568.0         1.07     35.00          298    Zn
# ..            ...          ...       ...          ...   ...
# 162         147.0         0.10      1.00          298    Cu
# 163        2850.0         1.00      1.00          273    Cu
# 164        2850.0         1.00      0.15          273    Cu
# 165         704.0         0.28      1.00          298    Zn
# 166         704.0         0.28      0.15          298    Zn
#
#                                 SMILE_Organic_linker_1  Atomic_Number  \
# 0                    OC(=O)C1=CC(=CC(=C1)C(O)=O)C(O)=O             29
# 1                    OC(=O)C1=CC(=CC(=C1)C(O)=O)C(O)=O             29
# ...

# %%
df.isnull().sum()
# Out:
# Surface_Area                        0
# Pore_Volume                         0
# Pressure                            0
# Temperature                         0
# METAL                               0
# SMILE_Organic_linker_1              0
# Atomic_Number                       0
# Molar_Mass_g_mol                    0
# Melting_Point_℃                     0
# Boiling_Point_℃                     0
# Electronegativity_Pauling           0
# Electron_Affinity_eV                0
# Density_g_cm3                       0
# Rayon_Atomique_pm                   0
# Thermal_Conductivity_W_m·K          0
# Electrical_Conductivity_MS_m        0
# Ionization_Potential_eV             0
# Molar_Volume_cm3_mol                0
# Specific_Heat_Capacity_J_(g·K)-1    0
# Mohs_Hardness                       0
# Resistivity_Ω_cm                    0
# CO2 Uptake                          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Check the garbage values
for i in df.select_dtypes(include="object").columns:
  print(df[i].value_counts())
  print("***"*10)
# Out:
# METAL
# Cu      55
# Zn      48
# Ni      13
# Mg      12
# Zr      10
# Cr       6
# Co       6
# Fe       4
# Al       4
# In       4
# Yb       2
# V        1
# Mg\n     1
# Zn\n     1
# Name: count, dtype: int64
# ******************************
# SMILE_Organic_linker_1
# C1=CC(=CC=C1C#CC2=CC(=NN2)C#C)C#C                                                                                           9
# C1=CC(=CC=C1C(=O)O)C(=O)O                                                                                                   8
# C(=O)(C(=O)O)C1=CC(=CC(=C1O)C(=O)[O-])C(=O)[O-]                                                                             8
# O=C(O)C1=CC=C(C=C1OC(=O)C2=CC=C(C=C2OC(=O)C3=CC(=C4C=CC(=C3)OCC(=O)C5=CC=CC=C5C4=C(C6=CC(=C(C=C6)Cl)OCCOC)Cl)OC)Cl)OCCOC    5
# C(=O)(C1=CC=C(C=C1)C(=O)O)C2=CC=CC=C2                                                                                       4
# ...

# %%
df.describe().T
# Out:
#                                   count         mean          std     min  \
# Surface_Area                      167.0  1865.102395  1352.925273   17.00
# Pore_Volume                       167.0     1.003832     1.027266    0.04
# Pressure                          167.0     8.438922    13.276858    0.10
# Temperature                       167.0   290.029940    20.886793  195.00
# Atomic_Number                     167.0    28.778443     8.233345   12.00
# Molar_Mass_g_mol                  167.0    63.133473    20.429815   24.31
# Melting_Point_℃                   167.0   955.240120   490.470804  156.60
# Boiling_Point_℃                   167.0  2099.964072  1009.149522  907.00
# Electronegativity_Pauling         167.0     1.715329     0.209091    1.10
# Electron_Affinity_eV              167.0     0.596467     0.555765    0.00
# Density_g_cm3                     167.0     7.377485     2.036507    1.74
# Rayon_Atomique_pm                 167.0   134.149701    11.550637  124.00
# ...
